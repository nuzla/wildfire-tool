# %%
import pandas as pd
from google.colab import files
import os

# %%
dates = pd.DataFrame(pd.date_range(start='1/1/2001', end='31/12/2020'), columns=['date'])

# %%
outfile='9amVPWesterAustralia.grid'

# %%
dates.shape

# %%
os.system('> '+outfile)
for index, row in dates.iterrows():
  try:
    d=row['date'].strftime('%Y%m%d')
    filename=d+d+'.grid'
    if (index%30)==0:
      print('Processing : '+d)
    r1=os.system('wget "http://www.bom.gov.au/web03/ncc/www/awap/vprp/vprph09/daily/grid/0.05/history/nat/'+filename+'.Z"')
    if r1==0:
      r2=os.system('uncompress '+filename+'.Z')
      if r2==0:
        r3=os.system(" grep '^ ' "+filename+" | sed 's/^ //' |  awk '{print \""+d+"\",NR-1,$0}' >> "+outfile)
    else:
      print("Download failed : "+filename+'.Z')
    os.remove(filename)
  except Exception as e:
      print(e)
# Out:
# Processing : 20010101
# Processing : 20010131
# Processing : 20010302
# Processing : 20010401
# Processing : 20010501
# Processing : 20010531
# Processing : 20010630
# Processing : 20010730
# Processing : 20010829
# Processing : 20010928
# Processing : 20011028
# Processing : 20011127
# Processing : 20011227
# Processing : 20020126
# Processing : 20020225
# Processing : 20020327
# Processing : 20020426
# Processing : 20020526
# Processing : 20020625
# Processing : 20020725
# Processing : 20020824
# Processing : 20020923
# Processing : 20021023
# Processing : 20021122
# Processing : 20021222
# Processing : 20030121
# Processing : 20030220
# Processing : 20030322
# Processing : 20030421
# Processing : 20030521
# Processing : 20030620
# Processing : 20030720
# Processing : 20030819
# Processing : 20030918
# Processing : 20031018
# Processing : 20031117
# Processing : 20031217
# Processing : 20040116
# Processing : 20040215
# Processing : 20040316
# Processing : 20040415
# Processing : 20040515
# Processing : 20040614
# Processing : 20040714
# Processing : 20040813
# Processing : 20040912
# Processing : 20041012
# Processing : 20041111
# Processing : 20041211
# Processing : 20050110
# Processing : 20050209
# Processing : 20050311
# Processing : 20050410
# Processing : 20050510
# Processing : 20050609
# Processing : 20050709
# Processing : 20050808
# Processing : 20050907
# Processing : 20051007
# Processing : 20051106
# Processing : 20051206
# Processing : 20060105
# Processing : 20060204
# Processing : 20060306
# Processing : 20060405
# Processing : 20060505
# Processing : 20060604
# Processing : 20060704
# Processing : 20060803
# Processing : 20060902
# Processing : 20061002
# Processing : 20061101
# Processing : 20061201
# Processing : 20061231
# Processing : 20070130
# Processing : 20070301
# Processing : 20070331
# Processing : 20070430
# Processing : 20070530
# Processing : 20070629
# Processing : 20070729
# Processing : 20070828
# Processing : 20070927
# Processing : 20071027
# Processing : 20071126
# Processing : 20071226
# Processing : 20080125
# Processing : 20080224
# Processing : 20080325
# Processing : 20080424
# Processing : 20080524
# Processing : 20080623
# Processing : 20080723
# Processing : 20080822
# Processing : 20080921
# Processing : 20081021
# Processing : 20081120
# Processing : 20081220
# Processing : 20090119
# Processing : 20090218
# Processing : 20090320
# Processing : 20090419
# Processing : 20090519
# Processing : 20090618
# Processing : 20090718
# Processing : 20090817
# [Errno 2] No such file or directory: '2009090220090902.grid'
# Processing : 20090916
# Processing : 20091016
# Processing : 20091115
# Processing : 20091215
# Processing : 20100114
# Processing : 20100213
# Processing : 20100315
# Processing : 20100414
# Processing : 20100514
# [Errno 2] No such file or directory: '2010052120100521.grid'
# Processing : 20100613
# Processing : 20100713
# Processing : 20100812
# Processing : 20100911
# Processing : 20101011
# Processing : 20101110
# Processing : 20101210
# Processing : 20110109
# Processing : 20110208
# Processing : 20110310
# Processing : 20110409
# Processing : 20110509
# Processing : 20110608
# Processing : 20110708
# Processing : 20110807
# Processing : 20110906
# Processing : 20111006
# Processing : 20111105
# [Errno 2] No such file or directory: '2011112520111125.grid'
# Processing : 20111205
# Processing : 20120104
# Processing : 20120203
# Processing : 20120304
# [Errno 2] No such file or directory: '2012032520120325.grid'
# Processing : 20120403
# Processing : 20120503
# Processing : 20120602
# Processing : 20120702
# Processing : 20120801
# Processing : 20120831
# Processing : 20120930
# Processing : 20121030
# Processing : 20121129
# Processing : 20121229
# Processing : 20130128
# Processing : 20130227
# Processing : 20130329
# Processing : 20130428
# Processing : 20130528
# Download failed : 2013060120130601.grid.Z
# [Errno 2] No such file or directory: '2013060120130601.grid'
# Processing : 20130627
# Processing : 20130727
# Processing : 20130826
# Processing : 20130925
# Processing : 20131025
# Processing : 20131124
# Processing : 20131224
# Processing : 20140123
# Processing : 20140222
# Processing : 20140324
# Processing : 20140423
# Processing : 20140523
# Processing : 20140622
# Processing : 20140722
# Processing : 20140821
# Processing : 20140920
# Processing : 20141020
# Processing : 20141119
# Processing : 20141219
# Processing : 20150118
# Processing : 20150217
# Processing : 20150319
# Processing : 20150418
# Processing : 20150518
# Processing : 20150617
# Processing : 20150717
# Processing : 20150816
# Processing : 20150915
# Processing : 20151015
# Processing : 20151114
# Processing : 20151214
# Processing : 20160113
# Processing : 20160212
# Processing : 20160313
# Processing : 20160412
# Processing : 20160512
# Processing : 20160611
# Processing : 20160711
# Processing : 20160810
# Processing : 20160909
# Processing : 20161009
# Processing : 20161108
# Processing : 20161208
# Processing : 20170107
# Processing : 20170206
# Processing : 20170308
# Processing : 20170407
# Processing : 20170507
# Processing : 20170606
# Processing : 20170706
# Processing : 20170805
# Processing : 20170904
# Processing : 20171004
# Processing : 20171103
# Processing : 20171203
# Processing : 20180102
# Processing : 20180201
# Processing : 20180303
# Processing : 20180402
# Processing : 20180502
# Processing : 20180601
# Processing : 20180701
# Processing : 20180731
# Processing : 20180830
# Processing : 20180929
# Processing : 20181029
# Processing : 20181128
# Processing : 20181228
# Processing : 20190127
# Processing : 20190226
# Processing : 20190328
# Processing : 20190427
# Processing : 20190527
# Processing : 20190626
# Processing : 20190726
# Processing : 20190825
# Processing : 20190924
# Processing : 20191024
# Processing : 20191123
# Processing : 20191223
# Processing : 20200122
# Processing : 20200221
# Processing : 20200322
# Processing : 20200421
# Processing : 20200521
# Processing : 20200620
# Processing : 20200720
# Processing : 20200819
# Processing : 20200918
# Processing : 20201018
# Processing : 20201117
# Processing : 20201217

# %%
# !ls -ltrh
# Out:
# total 30G
# -rw-r--r-- 1 root root 1.4M Aug 19  2010 2010052120100521.grid.Z
# -rw-r--r-- 1 root root 1.4M Feb 23  2012 2011112520111125.grid.Z
# -rw-r--r-- 1 root root 1.4M Jun 23  2012 2012032520120325.grid.Z
# -rw-r--r-- 1 root root 1.5M Mar 19  2013 2009090220090902.grid.Z
# drwxr-xr-x 1 root root 4.0K Jan  6 18:10 sample_data
# -rw-r--r-- 1 root root  30G Jan 11 04:21 9amVPWesterAustralia.grid

# %%
os.system('gzip '+outfile)

# %%
# !ls -ltrh
# Out:
# total 6.4G
# -rw-r--r-- 1 root root 1.4M Aug 19  2010 2010052120100521.grid.Z
# -rw-r--r-- 1 root root 1.4M Feb 23  2012 2011112520111125.grid.Z
# -rw-r--r-- 1 root root 1.4M Jun 23  2012 2012032520120325.grid.Z
# -rw-r--r-- 1 root root 1.5M Mar 19  2013 2009090220090902.grid.Z
# drwxr-xr-x 1 root root 4.0K Jan  6 18:10 sample_data
# -rw-r--r-- 1 root root 6.4G Jan 11 04:21 9amVPWesterAustralia.grid.gz

# %%
files.download('/content/'+outfile+'.gz')
